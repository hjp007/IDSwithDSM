# %%
import pandas as pd
from time import time
import matplotlib.pyplot as plt
import matplotlib
from sklearn import preprocessing

# %matplotlib inline
matplotlib.rcParams['font.sans-serif'] = ['SimHei']

# %%
print("Let's start")

#Data preprocessing
dataroot="../MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df=pd.read_csv(dataroot,header=0,low_memory=False)

#df = pd.concat([df1,df2,df3],axis=0,ignore_index=True)
pd.set_option('mode.use_inf_as_na', True) # convert inf to nan
df['Flow Bytes/s']=df['Flow Bytes/s'].astype('float64')
df[' Flow Packets/s']=df[' Flow Packets/s'].astype('float64')
df['Flow Bytes/s'].fillna(df['Flow Bytes/s'].mean(),inplace=True)
df[' Flow Packets/s'].fillna(df[' Flow Packets/s'].mean(),inplace=True)
df[' Label'] = df[' Label'].apply(lambda x: 0 if 'BENIGN' in x else 1)

df.drop(df[df[' Label'] == 0].index, inplace=True)

#train_test_split

#Feature scaling

scaler = preprocessing.MinMaxScaler()
print(df.values[0])
DDosMatrix=scaler.fit_transform(df.values)
print(DDosMatrix.shape)
print(DDosMatrix[0])
# Out:
# Let's start
# [8.00000000e+01 1.29379200e+06 3.00000000e+00 7.00000000e+00
#  2.60000000e+01 1.16070000e+04 2.00000000e+01 0.00000000e+00
#  8.66666667e+00 1.02632029e+01 5.84000000e+03 0.00000000e+00
#  1.65814286e+03 2.13729708e+03 8.99139893e+03 7.72921768e+00
#  1.43754667e+05 4.30865807e+05 1.29273000e+06 2.00000000e+00
#  7.47000000e+02 3.73500000e+02 5.23966125e+02 7.44000000e+02
#  3.00000000e+00 1.29374600e+06 2.15624333e+05 5.27671935e+05
#  1.29273000e+06 2.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.20000000e+01 1.52000000e+02
#  2.31876530e+00 5.41045238e+00 0.00000000e+00 5.84000000e+03
#  1.05754546e+03 1.85343753e+03 3.43523067e+06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.00000000e+00
#  1.16330000e+03 8.66666667e+00 1.65814286e+03 7.20000000e+01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.00000000e+00 2.60000000e+01
#  7.00000000e+00 1.16070000e+04 8.19200000e+03 2.29000000e+02
#  2.00000000e+00 2.00000000e+01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000000e+00]
# (128027, 79)
# [0.00000000e+00 1.24473024e-02 2.00000000e-01 8.75000000e-01
#  2.94117647e-01 9.99483338e-01 1.00000000e+00 0.00000000e+00
#  8.09523810e-01 7.25718036e-01 5.03665373e-01 0.00000000e+00
#  2.85862056e-01 2.60815818e-01 2.59111750e-05 3.84617407e-06
#  3.25236802e-03 7.49331838e-03 1.27993069e-02 3.16741995e-07
#  7.25242718e-06 8.45022624e-06 9.11245435e-06 7.36633663e-06
#  3.39366424e-07 2.09618620e-01 1.39792519e-01 1.71381286e-01
#  2.09796508e-01 5.26232700e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.45283019e-01 8.83720930e-01
#  1.54584354e-06 5.41045238e-06 0.00000000e+00 5.03408405e-01
#  5.45548517e-01 3.91721179e-01 1.53358512e-01 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.33333333e-01
#  4.99870757e-01 8.09523810e-01 2.85862056e-01 2.45283019e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.00000000e-01 2.94117647e-01
#  8.75000000e-01 9.99483338e-01 2.80547945e-01 1.00000000e+00
#  2.22222222e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
dataroot2="../MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df2=pd.read_csv(dataroot,header=0,low_memory=False)

#df = pd.concat([df1,df2,df3],axis=0,ignore_index=True)
pd.set_option('mode.use_inf_as_na', True) # convert inf to nan
df2['Flow Bytes/s']=df2['Flow Bytes/s'].astype('float64')
df2[' Flow Packets/s']=df2[' Flow Packets/s'].astype('float64')
df2['Flow Bytes/s'].fillna(df2['Flow Bytes/s'].mean(),inplace=True)
df2[' Flow Packets/s'].fillna(df2[' Flow Packets/s'].mean(),inplace=True)
df2[' Label'] = df2[' Label'].apply(lambda x: 0 if 'BENIGN' in x else 1)

df2.drop(df2[df2[' Label'] == 1].index, inplace=True)

#train_test_split

#Feature scaling
BenignMatrix=scaler.fit_transform(df2.values)
print(BenignMatrix.shape)
print(BenignMatrix[0])
# Out:
# (97718, 79)
# [8.37224562e-01 3.33333506e-08 5.17866390e-04 0.00000000e+00
#  6.55694709e-05 0.00000000e+00 5.13698630e-04 4.07608696e-03
#  1.55159038e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.68491835e-03 5.33333333e-01
#  3.73831772e-08 0.00000000e+00 3.33333331e-08 5.60747648e-08
#  2.50000000e-08 2.50000000e-08 0.00000000e+00 2.50000000e-08
#  2.50000000e-08 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.01533151e-03 0.00000000e+00
#  2.22222222e-01 0.00000000e+00 1.78041543e-02 5.13698630e-04
#  3.09784012e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.56012658e-03 1.55159038e-03 0.00000000e+00 1.01533151e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.17866390e-04 6.55694709e-05
#  0.00000000e+00 0.00000000e+00 5.18798828e-04 0.00000000e+00
#  5.17866390e-04 3.84615385e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
for i in range(78):
    print("第{}个属性的分布".format(i+1))
    plt.title("DDos")
    plt.hist(DDosMatrix[:,i],20)
    plt.show()
    plt.title("Benign")
    plt.hist(BenignMatrix[:,i],20)
    plt.show()
# Out:
# 第1个属性的分布
# 第2个属性的分布
# 第3个属性的分布
# 第4个属性的分布
# 第5个属性的分布
# 第6个属性的分布
# 第7个属性的分布
# 第8个属性的分布
# 第9个属性的分布
# 第10个属性的分布
# 第11个属性的分布
# 第12个属性的分布
# 第13个属性的分布
# 第14个属性的分布
# 第15个属性的分布
# 第16个属性的分布
# 第17个属性的分布
# 第18个属性的分布
# 第19个属性的分布
# 第20个属性的分布
# 第21个属性的分布
# 第22个属性的分布
# 第23个属性的分布
# 第24个属性的分布
# 第25个属性的分布
# 第26个属性的分布
# 第27个属性的分布
# 第28个属性的分布
# 第29个属性的分布
# 第30个属性的分布
# 第31个属性的分布
# 第32个属性的分布
# 第33个属性的分布
# 第34个属性的分布
# 第35个属性的分布
# 第36个属性的分布
# 第37个属性的分布
# 第38个属性的分布
# 第39个属性的分布
# 第40个属性的分布
# 第41个属性的分布
# 第42个属性的分布
# 第43个属性的分布
# 第44个属性的分布
# 第45个属性的分布
# 第46个属性的分布
# 第47个属性的分布
# 第48个属性的分布
# 第49个属性的分布
# 第50个属性的分布
# 第51个属性的分布
# 第52个属性的分布
# 第53个属性的分布
# 第54个属性的分布
# 第55个属性的分布
# 第56个属性的分布
# 第57个属性的分布
# 第58个属性的分布
# 第59个属性的分布
# 第60个属性的分布
# 第61个属性的分布
# 第62个属性的分布
# 第63个属性的分布
# 第64个属性的分布
# 第65个属性的分布
# 第66个属性的分布
# 第67个属性的分布
# 第68个属性的分布
# 第69个属性的分布
# 第70个属性的分布
# 第71个属性的分布
# 第72个属性的分布
# 第73个属性的分布
# 第74个属性的分布
# 第75个属性的分布
# 第76个属性的分布
# 第77个属性的分布
# 第78个属性的分布

# %%
print(DDosMatrix[:,2])
print(BenignMatrix[:,2])
intervals = {}
intervals = {'{0}-{1}'.format(0.05 * x, 0.05 * (x+1) ): 0 for x in range(20)}
intervals['count'] = 0
for _ in DDosMatrix[:,2]:
    for interval in intervals:
        if(interval != 'count'):
            print(interval)
            start, end = tuple(interval.split('-'))
            #print(start)
            #print(end)
            #print(_)
            if float(start) <= _ <= float(end):
                intervals[interval] += 1
                intervals['count']+=1
print(intervals)
# Out:
# [0.2 0.3 0.2 ... 0.3 0.2 0.3]
# [0.00051787 0.         0.         ... 0.         0.00051787 0.        ]
# 0.0-0.05
# 0.05-0.1
# 0.1-0.15000000000000002
# 0.15000000000000002-0.2
# 0.2-0.25
# 0.25-0.30000000000000004
# 0.30000000000000004-0.35000000000000003
# 0.35000000000000003-0.4
# 0.4-0.45
# 0.45-0.5
# 0.5-0.55
# 0.55-0.6000000000000001
# 0.6000000000000001-0.65
# 0.65-0.7000000000000001
# 0.7000000000000001-0.75
# 0.75-0.8
# 0.8-0.8500000000000001
# 0.8500000000000001-0.9
# 0.9-0.9500000000000001
# 0.9500000000000001-1.0
# count
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-e7f6a0e57d7f> in <module>
#       7     for interval in intervals:
#       8         print(interval)
# ----> 9         start, end = tuple(interval.split('-'))
#      10         #print(start)
#      11         #print(end)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
lst = [1, 1, 1, 2, 3, 4, 4, 5, 5, 6, 7, 7, 7, 7, 8, 9, 9, 9, 10, 99, 99, 99, 100, 100]
intervals = {'{0}-{1}'.format(10 * x + 1, 10 * (x + 1)): 0 for x in range(10)}
for _ in lst:
    for interval in intervals:
        start, end = tuple(interval.split('-'))
        if int(start) <= _ <= int(end):
            intervals[interval] += 1
print(intervals)
# Out:
# {'1-10': 19, '11-20': 0, '21-30': 0, '31-40': 0, '41-50': 0, '51-60': 0, '61-70': 0, '71-80': 0, '81-90': 0, '91-100': 5}
